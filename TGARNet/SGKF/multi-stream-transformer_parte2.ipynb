# %% [markdown]
# # Clonamos el repositorio con los modelos y herramientas¶

# %%
# !git clone https://github.com/dannasalazar11/Msc_thesis.git
# Out:
# Cloning into 'Msc_thesis'...
# remote: Enumerating objects: 478, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 478 (delta 30), reused 0 (delta 0), pack-reused 427 (from 1)
# Receiving objects: 100% (478/478), 50.49 MiB | 45.43 MiB/s, done.
# Resolving deltas: 100% (307/307), done.

# %%
import sys
sys.path.append('/kaggle/working/Msc_thesis')

from gmrrnet_adhd.utils import get_segmented_data, train_L24O_cv
from tensorflow.keras.mixed_precision import set_global_policy
set_global_policy('mixed_float16')


import tensorflow as tf
import numpy as np
import random
import os

# Establecer semilla
seed = 42

# Semillas para módulos principales
np.random.seed(seed)
random.seed(seed)
tf.random.set_seed(seed)
# Out:
# 2025-07-16 14:22:58.139656: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752675778.354193      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752675778.414958      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Importar base de datos segmentada (Segmentos de 4 seg con translape del 50%, es decir, de 2 seg)

# %%
from gmrrnet_adhd.models.spatio_temporal import prepare_streams_4s

X, y, sbjs = get_segmented_data()
X.shape, y.shape, len(sbjs)
# Out:
# ((8213, 19, 512), (8213, 2), 8213)

# %% [markdown]
# ## Preprocesamiento de los datos mencionado por la propuesta
#
# | Variable   | Forma resultante | Cálculo exacto                                                                                                                                                                                                                |
# | ---------- | ---------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **`freq`** | `(N, 20, 1)`     | - PSD con `welch(signal, fs=128, nperseg=512)`.<br>- Potencia media en **20 bandas log‑espaciadas** entre 1 Hz y 64 Hz.<br>- Promedio sobre canales → vector de 20.<br>- Se añade un eje final de tamaño 1.                   |
# | **`temp`** | `(N, 10, 1)`     | - Se recortan 510 muestras (de 512).<br>- Se dividen en **10 ventanas** consecutivas de 51 muestras (≈ 400 ms).<br>- **Media aritmética** dentro de cada ventana promediando canales.<br>- Se añade un eje final de tamaño 1. |
# | **`spat`** | `(N, C, 1)`      | - Para cada canal: **RMS** del segmento `sqrt(mean(x**2))`.<br>- Se añade un eje final de tamaño 1.                                                                                                                           |

# %%
freq, temp, spat = prepare_streams_4s(X, fs=128)

freq.shape, temp.shape, spat.shape
# Out:
# ((8213, 20, 1), (8213, 10, 1), (8213, 19, 1))

# %%
from sklearn.preprocessing import StandardScaler

scaler_f = StandardScaler().fit(freq.reshape(-1, 20))
scaler_t = StandardScaler().fit(temp.reshape(-1, 10))
scaler_s = StandardScaler().fit(spat.reshape(-1, spat.shape[1]))

freq = scaler_f.transform(freq.reshape(-1, 20)).reshape(freq.shape)
temp = scaler_t.transform(temp.reshape(-1, 10)).reshape(temp.shape)
spat = scaler_s.transform(spat.reshape(-1, spat.shape[1])).reshape(spat.shape)

# %% [markdown]
# # Importamos el modelo y definimos los hiperparámetros

# %%
from gmrrnet_adhd.models.spatio_temporal import build_eeg_attention_model
from tensorflow.keras.optimizers import Adam

model_name="spatio_temporal"

model_args =    {'freq_shape' : freq.shape[1:],   # (20,1)
                 'temp_shape' : temp.shape[1:],   # (10,1)
                 'spat_shape' : spat.shape[1:]}   # (19,1)

compile_args = {'optimizer':lambda: Adam(1e-4, clipnorm=1.0),
    "loss": "categorical_crossentropy",
    "metrics": ["accuracy"]
}

model = build_eeg_attention_model(
    **model_args
)

model.summary()
# Out:
# I0000 00:00:1752675883.765822      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1752675883.766514      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "EEG_Attention_Transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ freq_input (InputLayer)   │ (None, 20, 1)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ temp_input (InputLayer)   │ (None, 10, 1)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spat_input (InputLayer)   │ (None, 19, 1)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast (Cast)               │ (None, 20, 1)          │              0 │ freq_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast_2 (Cast)             │ (None, 10, 1)          │              0 │ temp_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast_4 (Cast)             │ (None, 19, 1)          │              0 │ spat_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 20, 64)         │            128 │ cast[0][0]             │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 10, 64)         │            128 │ cast_2[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_12 (Dense)          │ (None, 19, 64)         │            128 │ cast_4[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ positional_encoding       │ (None, 20, 64)         │              0 │ dense[0][0]            │
# │ (PositionalEncoding)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ positional_encoding_1     │ (None, 10, 64)         │              0 │ dense_6[0][0]          │
# │ (PositionalEncoding)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ positional_encoding_2     │ (None, 19, 64)         │              0 │ dense_12[0][0]         │
# │ (PositionalEncoding)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast_1 (Cast)             │ (None, 20, 64)         │              0 │ positional_encoding[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast_3 (Cast)             │ (None, 10, 64)         │              0 │ positional_encoding_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ cast_5 (Cast)             │ (None, 19, 64)         │              0 │ positional_encoding_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder_block │ (None, 20, 64)         │         83,200 │ cast_1[0][0]           │
# │ (TransformerEncoderBlock) │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder_bloc… │ (None, 10, 64)         │         83,200 │ cast_3[0][0]           │
# │ (TransformerEncoderBlock) │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder_bloc… │ (None, 19, 64)         │         83,200 │ cast_5[0][0]           │
# │ (TransformerEncoderBlock) │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder_bloc… │ (None, 20, 64)         │         83,200 │ transformer_encoder_b… │
# │ (TransformerEncoderBlock) │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder_bloc… │ (None, 10, 64)         │         83,200 │ transformer_encoder_b… │
# │ (TransformerEncoderBlock) │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder_bloc… │ (None, 19, 64)         │         83,200 │ transformer_encoder_b… │
# │ (TransformerEncoderBlock) │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d  │ (None, 64)             │              0 │ transformer_encoder_b… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 64)             │              0 │ transformer_encoder_b… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 64)             │              0 │ transformer_encoder_b… │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 128)            │          8,320 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_11 (Dense)          │ (None, 128)            │          8,320 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 128)            │          8,320 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concat_streams            │ (None, 384)            │              0 │ dense_5[0][0],         │
# │ (Concatenate)             │                        │                │ dense_11[0][0],        │
# │                           │                        │                │ dense_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 128)            │         49,280 │ concat_streams[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_18 (Dropout)      │ (None, 128)            │              0 │ dense_18[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attention_state (Dense)   │ (None, 2)              │            258 │ dropout_18[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 574,082 (2.19 MB)
#  Trainable params: 574,082 (2.19 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Resultados - Leave 24 Subjects Out

# %%
import os

import pickle

with open("/kaggle/input/ieee-tdah-control-database/folds.pkl", "rb") as f:
    folds = pickle.load(f)

# %%
# X_total is a list: [freq, temp, spat]

# %%
import numpy as np

X_total = [freq, temp, spat]            # each array shape (N, …)

results = {}

for i in range(4):
    result = train_L24O_cv(build_eeg_attention_model, X_total, y, sbjs, model_args, compile_args, folds, model_name='spatio_temporal')
    results[i] = result
# Out:
# Fold 1/5. Test subjects: ['v28p', 'v274', 'v1p', 'v231', 'v22p', 'v29p', 'v206', 'v238', 'v31p', 'v35p', 'v177', 'v200', 'v112', 'v113', 'v48p', 'v140', 'v131', 'v125', 'v55p', 'v143', 'v43p', 'v305', 'v134', 'v114']
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752675917.527566      74 service.cc:148] XLA service 0x7dfbfc0129c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752675917.528195      74 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752675917.528224      74 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1752675921.884351      74 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1752675939.197132      74 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step
# Fold metrics: {'accuracy': 0.733013040494166, 'recall': 0.7284001314060446, 'precision': 0.740350113843623, 'kappa': 0.4605588640358934, 'auc': 0.7284001314060446}
# Fold 2/5. Test subjects: ['v18p', 'v39p', 'v234', 'v32p', 'v190', 'v6p', 'v254', 'v204', 'v24p', 'v183', 'v246', 'v219', 'v298', 'v41p', 'v47p', 'v308', 'v52p', 'v300', 'v59p', 'v299', 'v302', 'v51p', 'v109', 'v127']
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step
# Fold metrics: {'accuracy': 0.6258992805755396, 'recall': 0.5881130428319297, 'precision': 0.6578241858643868, 'kappa': 0.18854011878384547, 'auc': 0.5881130428319297}
# Fold 3/5. Test subjects: ['v215', 'v3p', 'v209', 'v37p', 'v213', 'v15p', 'v284', 'v181', 'v19p', 'v34p', 'v263', 'v244', 'v138', 'v121', 'v46p', 'v54p', 'v120', 'v310', 'v147', 'v50p', 'v56p', 'v107', 'v297', 'v108']
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step
# Fold metrics: {'accuracy': 0.8184389140271493, 'recall': 0.8055409886378042, 'precision': 0.8127366247275231, 'kappa': 0.6174233333962503, 'auc': 0.8055409886378042}
# Fold 4/5. Test subjects: ['v227', 'v8p', 'v236', 'v14p', 'v196', 'v27p', 'v33p', 'v179', 'v173', 'v10p', 'v265', 'v20p', 'v57p', 'v45p', 'v111', 'v115', 'v53p', 'v118', 'v123', 'v44p', 'v149', 'v303', 'v116', 'v151']
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step
# Fold metrics: {'accuracy': 0.7646710136336692, 'recall': 0.7415972473221918, 'precision': 0.7803035597800765, 'kappa': 0.5015031443591708, 'auc': 0.7415972473221918}
# Fold 5/5. Test subjects: ['v279', 'v30p', 'v288', 'v286', 'v250', 'v12p', 'v38p', 'v25p', 'v21p', 'v40p', 'v198', 'v270', 'v117', 'v306', 'v309', 'v110', 'v42p', 'v58p', 'v307', 'v133', 'v304', 'v129', 'v49p', 'v60p']
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step
# Fold metrics: {'accuracy': 0.7911818738518065, 'recall': 0.7905367676858648, 'precision': 0.7915406467083186, 'kappa': 0.5816554440092947, 'auc': 0.7905367676858648}
# Fold 1/5. Test subjects: ['v28p', 'v274', 'v1p', 'v231', 'v22p', 'v29p', 'v206', 'v238', 'v31p', 'v35p', 'v177', 'v200', 'v112', 'v113', 'v48p', 'v140', 'v131', 'v125', 'v55p', 'v143', 'v43p', 'v305', 'v134', 'v114']
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step
# Fold metrics: {'accuracy': 0.7522306108442004, 'recall': 0.7453243237119942, 'precision': 0.7750640360718898, 'kappa': 0.49702264548969277, 'auc': 0.7453243237119941}
# Fold 2/5. Test subjects: ['v18p', 'v39p', 'v234', 'v32p', 'v190', 'v6p', 'v254', 'v204', 'v24p', 'v183', 'v246', 'v219', 'v298', 'v41p', 'v47p', 'v308', 'v52p', 'v300', 'v59p', 'v299', 'v302', 'v51p', 'v109', 'v127']
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step
# Fold metrics: {'accuracy': 0.6342925659472423, 'recall': 0.6032657724948153, 'precision': 0.6478216514266759, 'kappa': 0.21786575775884742, 'auc': 0.6032657724948153}
# Fold 3/5. Test subjects: ['v215', 'v3p', 'v209', 'v37p', 'v213', 'v15p', 'v284', 'v181', 'v19p', 'v34p', 'v263', 'v244', 'v138', 'v121', 'v46p', 'v54p', 'v120', 'v310', 'v147', 'v50p', 'v56p', 'v107', 'v297', 'v108']
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step
# Fold metrics: {'accuracy': 0.8156108597285068, 'recall': 0.8117878611984015, 'precision': 0.8072711396563265, 'kappa': 0.6185524572436039, 'auc': 0.8117878611984014}
# Fold 4/5. Test subjects: ['v227', 'v8p', 'v236', 'v14p', 'v196', 'v27p', 'v33p', 'v179', 'v173', 'v10p', 'v265', 'v20p', 'v57p', 'v45p', 'v111', 'v115', 'v53p', 'v118', 'v123', 'v44p', 'v149', 'v303', 'v116', 'v151']
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step
# Fold metrics: {'accuracy': 0.6680497925311203, 'recall': 0.6523381697389029, 'precision': 0.6605526498775585, 'kappa': 0.31020584593097966, 'auc': 0.6523381697389029}
# Fold 5/5. Test subjects: ['v279', 'v30p', 'v288', 'v286', 'v250', 'v12p', 'v38p', 'v25p', 'v21p', 'v40p', 'v198', 'v270', 'v117', 'v306', 'v309', 'v110', 'v42p', 'v58p', 'v307', 'v133', 'v304', 'v129', 'v49p', 'v60p']
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step
# Fold metrics: {'accuracy': 0.8285364360073484, 'recall': 0.829321084943186, 'precision': 0.8296813437478399, 'kappa': 0.6574539940726446, 'auc': 0.829321084943186}
# Fold 1/5. Test subjects: ['v28p', 'v274', 'v1p', 'v231', 'v22p', 'v29p', 'v206', 'v238', 'v31p', 'v35p', 'v177', 'v200', 'v112', 'v113', 'v48p', 'v140', 'v131', 'v125', 'v55p', 'v143', 'v43p', 'v305', 'v134', 'v114']
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step
# Fold metrics: {'accuracy': 0.7378174330816747, 'recall': 0.7333061458758137, 'precision': 0.7450337691798233, 'kappa': 0.4703643294742792, 'auc': 0.7333061458758137}
# Fold 2/5. Test subjects: ['v18p', 'v39p', 'v234', 'v32p', 'v190', 'v6p', 'v254', 'v204', 'v24p', 'v183', 'v246', 'v219', 'v298', 'v41p', 'v47p', 'v308', 'v52p', 'v300', 'v59p', 'v299', 'v302', 'v51p', 'v109', 'v127']
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step
# Fold metrics: {'accuracy': 0.6163069544364509, 'recall': 0.5816406688362697, 'precision': 0.6295540800255326, 'kappa': 0.17348384549276474, 'auc': 0.5816406688362699}
# Fold 3/5. Test subjects: ['v215', 'v3p', 'v209', 'v37p', 'v213', 'v15p', 'v284', 'v181', 'v19p', 'v34p', 'v263', 'v244', 'v138', 'v121', 'v46p', 'v54p', 'v120', 'v310', 'v147', 'v50p', 'v56p', 'v107', 'v297', 'v108']
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step
# Fold metrics: {'accuracy': 0.8195701357466063, 'recall': 0.8179466650654177, 'precision': 0.8114399690486647, 'kappa': 0.6282404184859415, 'auc': 0.8179466650654177}
# Fold 4/5. Test subjects: ['v227', 'v8p', 'v236', 'v14p', 'v196', 'v27p', 'v33p', 'v179', 'v173', 'v10p', 'v265', 'v20p', 'v57p', 'v45p', 'v111', 'v115', 'v53p', 'v118', 'v123', 'v44p', 'v149', 'v303', 'v116', 'v151']
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step
# Fold metrics: {'accuracy': 0.7628927089508002, 'recall': 0.7549511482877518, 'precision': 0.7586234490304258, 'kappa': 0.513068075219004, 'auc': 0.7549511482877518}
# Fold 5/5. Test subjects: ['v279', 'v30p', 'v288', 'v286', 'v250', 'v12p', 'v38p', 'v25p', 'v21p', 'v40p', 'v198', 'v270', 'v117', 'v306', 'v309', 'v110', 'v42p', 'v58p', 'v307', 'v133', 'v304', 'v129', 'v49p', 'v60p']
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step
# Fold metrics: {'accuracy': 0.7960808328230251, 'recall': 0.7950195884180664, 'precision': 0.7975655175546168, 'kappa': 0.591126560092754, 'auc': 0.7950195884180664}
# Fold 1/5. Test subjects: ['v28p', 'v274', 'v1p', 'v231', 'v22p', 'v29p', 'v206', 'v238', 'v31p', 'v35p', 'v177', 'v200', 'v112', 'v113', 'v48p', 'v140', 'v131', 'v125', 'v55p', 'v143', 'v43p', 'v305', 'v134', 'v114']
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step
# Fold metrics: {'accuracy': 0.7206588881262869, 'recall': 0.717493996103131, 'precision': 0.7228587015821059, 'kappa': 0.43726863208599076, 'auc': 0.717493996103131}
# Fold 2/5. Test subjects: ['v18p', 'v39p', 'v234', 'v32p', 'v190', 'v6p', 'v254', 'v204', 'v24p', 'v183', 'v246', 'v219', 'v298', 'v41p', 'v47p', 'v308', 'v52p', 'v300', 'v59p', 'v299', 'v302', 'v51p', 'v109', 'v127']
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step
# Fold metrics: {'accuracy': 0.6366906474820144, 'recall': 0.6000419735129644, 'precision': 0.6722413061970085, 'kappa': 0.21361276258730855, 'auc': 0.6000419735129645}
# Fold 3/5. Test subjects: ['v215', 'v3p', 'v209', 'v37p', 'v213', 'v15p', 'v284', 'v181', 'v19p', 'v34p', 'v263', 'v244', 'v138', 'v121', 'v46p', 'v54p', 'v120', 'v310', 'v147', 'v50p', 'v56p', 'v107', 'v297', 'v108']
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step
# Fold metrics: {'accuracy': 0.8286199095022625, 'recall': 0.819262357972552, 'precision': 0.8220015073212747, 'kappa': 0.6411280165922624, 'auc': 0.819262357972552}
# Fold 4/5. Test subjects: ['v227', 'v8p', 'v236', 'v14p', 'v196', 'v27p', 'v33p', 'v179', 'v173', 'v10p', 'v265', 'v20p', 'v57p', 'v45p', 'v111', 'v115', 'v53p', 'v118', 'v123', 'v44p', 'v149', 'v303', 'v116', 'v151']
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step
# Fold metrics: {'accuracy': 0.7617071724955542, 'recall': 0.7487708186319226, 'precision': 0.7604646273520446, 'kappa': 0.5056889496617243, 'auc': 0.7487708186319225}
# Fold 5/5. Test subjects: ['v279', 'v30p', 'v288', 'v286', 'v250', 'v12p', 'v38p', 'v25p', 'v21p', 'v40p', 'v198', 'v270', 'v117', 'v306', 'v309', 'v110', 'v42p', 'v58p', 'v307', 'v133', 'v304', 'v129', 'v49p', 'v60p']
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step
# Fold metrics: {'accuracy': 0.8077158603796694, 'recall': 0.808195613995587, 'precision': 0.808107743097239, 'kappa': 0.6156362486076277, 'auc': 0.808195613995587}

# %%
for i in range(4):
    result = results[i]
    accs = []
    for r in result:
        accs.append(r['accuracy'])
    
    print(i, '->', np.mean(accs))
# Out:
# 0 -> 0.7466408245164661
# 1 -> 0.7397440530116837
# 2 -> 0.7465336130077115
# 3 -> 0.7510784955971574

# %%
import pickle

with open(f'results_L24SO_{model_name}.pkl', 'wb') as f:
    pickle.dump(results, f)

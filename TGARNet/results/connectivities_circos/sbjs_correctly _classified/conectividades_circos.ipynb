# %% [markdown]
# ahora veamos los circos de los dos sujetos

# %%
import pickle

with open("/kaggle/input/pesos-atencion/convex_kernel_v270_v2.pkl", "rb") as f:
    v270 = pickle.load(f)

with open("/kaggle/input/pesos-atencion/convex_kernel_v307_v2.pkl", "rb") as f:
    v307 = pickle.load(f)

# %%
v270.shape
# Out:
# (91, 19, 19, 1)

# %%
channels = ["Fz","Cz","Pz","C3","T3","C4","T4","Fp1","Fp2","F3","F4","F7","F8","P3","P4","T5","T6","O1","O2"]

areas = {
    'Frontal': ['Fz'],
    'Frontal Right': ['Fp2', 'F4', 'F8'],
    'Central \nRight': ['C4'],
    'Posterior Right': ['P4', 'O2'],
    'Posterior': ['Pz', 'Cz'],
    'Posterior Left': ['P3', 'O1'],
    'Central \nLeft': ['C3'],
    'Frontal Left': ['Fp1', 'F3', 'F7'],
    'Temporal Left': ['T3', 'T5'],
    'Temporal Right': ['T4', 'T6']
}

n_channels = len(channels)

# %%
pip install -U git+https://github.com/UN-GCPDS/python-gcpds.visualizations.git
# Out:
# Collecting git+https://github.com/UN-GCPDS/python-gcpds.visualizations.git
#   Cloning https://github.com/UN-GCPDS/python-gcpds.visualizations.git to /tmp/pip-req-build-s5i96hcw
#   Running command git clone --filter=blob:none --quiet https://github.com/UN-GCPDS/python-gcpds.visualizations.git /tmp/pip-req-build-s5i96hcw
#   Resolved https://github.com/UN-GCPDS/python-gcpds.visualizations.git to commit 162dbeac141a7472d3b0bd7f005932241b4663a5
#   Preparing metadata (setup.py) ... done
# Collecting python-circos (from gcpds-visualizations==0.6)
#   Downloading python_circos-0.3.0-py3-none-any.whl.metadata (766 bytes)
# Requirement already satisfied: matplotlib>=3.5.3 in /usr/local/lib/python3.11/dist-packages (from gcpds-visualizations==0.6) (3.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from gcpds-visualizations==0.6) (1.26.4)
# Requirement already satisfied: mne in /usr/local/lib/python3.11/dist-packages (from gcpds-visualizations==0.6) (1.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->gcpds-visualizations==0.6) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->gcpds-visualizations==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->gcpds-visualizations==0.6) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->gcpds-visualizations==0.6) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->gcpds-visualizations==0.6) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->gcpds-visualizations==0.6) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->gcpds-visualizations==0.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5.3->gcpds-visualizations==0.6) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->gcpds-visualizations==0.6) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->gcpds-visualizations==0.6) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->gcpds-visualizations==0.6) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->gcpds-visualizations==0.6) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->gcpds-visualizations==0.6) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->gcpds-visualizations==0.6) (2.4.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from mne->gcpds-visualizations==0.6) (4.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from mne->gcpds-visualizations==0.6) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.11/dist-packages (from mne->gcpds-visualizations==0.6) (0.4)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.11/dist-packages (from mne->gcpds-visualizations==0.6) (1.8.2)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from mne->gcpds-visualizations==0.6) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mne->gcpds-visualizations==0.6) (4.67.1)
# Collecting biopython>=1.78 (from python-circos->gcpds-visualizations==0.6)
#   Downloading biopython-1.86-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne->gcpds-visualizations==0.6) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.5->mne->gcpds-visualizations==0.6) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.3->gcpds-visualizations==0.6) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->mne->gcpds-visualizations==0.6) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->gcpds-visualizations==0.6) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->gcpds-visualizations==0.6) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->gcpds-visualizations==0.6) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->gcpds-visualizations==0.6) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->gcpds-visualizations==0.6) (2024.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne->gcpds-visualizations==0.6) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne->gcpds-visualizations==0.6) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne->gcpds-visualizations==0.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.5->mne->gcpds-visualizations==0.6) (2025.6.15)
# Downloading python_circos-0.3.0-py3-none-any.whl (27 kB)
# Downloading biopython-1.86-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 323.7 kB/s eta 0:00:00
# Building wheels for collected packages: gcpds-visualizations
#   Building wheel for gcpds-visualizations (setup.py) ... done
#   Created wheel for gcpds-visualizations: filename=gcpds_visualizations-0.6-py3-none-any.whl size=12440 sha256=2e642d91ed09cdcfeac296a44dc3681882aa477fbf42e6cb5184941a3d9bddd4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s6mc_wga/wheels/12/e9/11/f7246de13d1d668c154d68fb1260be82dbfbc166301807d756
# Successfully built gcpds-visualizations
# Installing collected packages: biopython, python-circos, gcpds-visualizations
# Successfully installed biopython-1.86 gcpds-visualizations-0.6 python-circos-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from gcpds.visualizations.connectivities import CircosConnectivity
import matplotlib.pyplot as plt

def plot_circos(connectivities, eeg_ch_names, areas, threshold=0.6):
    """
    input
    connectivities: tensorflow square array
    """
    conn = CircosConnectivity(connectivities, eeg_ch_names, areas=areas, threshold=threshold,
    # cmaps and themes
    areas_cmap='PuRd',
    arcs_cmap='Wistia',
    hemisphere_color='lightgray',
    channel_color='#f8f9fa',
    min_alpha=0,
    # Texts
    width={'hemispheres':50, 'areas':100, 'channels':60},
    text={'hemispheres':40, 'areas':25,  'channels':40},
    separation={'hemispheres':10, 'areas':-30, 'channels':5},
    labelposition={'hemispheres':60, 'areas':-10, 'channels':-10},
    size=10,
    labelsize=17,
    # Shapes
    show_emisphere=True,
    arcs_separation=30,
    connection_width=0.1,
    small_separation=5,
    big_separation=10,
    offset=0,
    )

# %%
import numpy as np

print("ADHD subejct")
relations = np.mean(v270, axis=(0,-1))
p90 = np.percentile(relations, 90)
plot_circos(relations, channels, areas, threshold=p90)
plt.savefig("circos_adhd_v270.pdf")
plt.show()
# Out:
# ADHD subejct

# %%
print("Control subejct")

relations = np.mean(v307, axis=(0,-1))
p90 = np.percentile(relations, 90)
plot_circos(relations, channels, areas, threshold=p90)
plt.savefig("circos_control_v307.pdf")
plt.show()
# Out:
# Control subejct
